# %%
import sys
from IPython.core.display import display, HTML
display(HTML("<style>div.output_scroll { height: 500em; }</style>"))

from IPython.display import Image
display(Image(filename= "./img/help.png",width=200,height=100))
print("Hi...\nI'm your bot.")
flag=True
while(flag):
    print("\nPress:  \n1 for recent stats and\n2 for queries\n3 to exit")
    try:
        option=int(input())
    except ValueError:
        print("Oops!  That was no valid number.  Try again...")
    if(option==1):
        print("Here are the latest stats:\n")      
        # %run vizualizationcopy.ipynb
        display(HTML(latest_data[['Cured/Discharged/Migrated','Date','Death','Name of State / UT','Total Confirmed cases','Active']].to_html()))  
        
        flag=True
    elif(option==2):
        flag=True
        # %run nlp_chatbotcopy.ipynb
    elif(option==3):
        print("*****************************************************")
        break
    else:
        print("That's not a correct option.\n")
        try:
            option=int(input())
        except ValueError:
            print("Oops!  That was no valid number.  Try again...")
        flag=True
print("\nBye !! Stay Safe!!")
display(Image(filename='./img/help.gif',width=200,height=100))
# Out:
# <style>div.output_scroll { height: 500em; }</style>
# Hi...
# I'm your bot.
#
# Press:
# 1 for recent stats and
# 2 for queries
# 3 to exit
# 1
# Here are the latest stats:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
# ...
